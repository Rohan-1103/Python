# %% [markdown]
# # Filtering and Ordering

# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\vgSales.csv")

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df[df['Year'] >= 2015.0]
# Out:
#         Rank                                               Name Platform  \
# 33        34                          Call of Duty: Black Ops 3      PS4
# 77        78                                            FIFA 16      PS4
# 92        93                       Star Wars Battlefront (2015)      PS4
# 101      102                          Call of Duty: Black Ops 3     XOne
# 109      110                                          Fallout 4      PS4
# ...      ...                                                ...      ...
# 16565  16568                                          Teslagrad      PSV
# 16569  16572                                 Resident Evil 4 HD     XOne
# 16570  16573                      Farming 2017 - The Simulation      PS4
# 16576  16579                                  Rugby Challenge 3     XOne
# 16589  16592  Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shiru...      PSV
#
#          Year         Genre             Publisher  NA_Sales  EU_Sales  \
# ...

# %%
specific_platform = ['PS4', 'PC']
df[df['Platform'].isin(specific_platform)]
# Out:
#         Rank                           Name Platform    Year       Genre  \
# 33        34      Call of Duty: Black Ops 3      PS4  2015.0     Shooter
# 44        45             Grand Theft Auto V      PS4  2014.0      Action
# 77        78                        FIFA 16      PS4  2015.0      Sports
# 83        84                     The Sims 3       PC  2009.0  Simulation
# 92        93   Star Wars Battlefront (2015)      PS4  2015.0     Shooter
# ...      ...                            ...      ...     ...         ...
# 16566  16569                 End of Nations       PC  2012.0    Strategy
# 16570  16573  Farming 2017 - The Simulation      PS4  2016.0  Simulation
# 16577  16580                      Damnation       PC  2009.0     Shooter
# 16585  16588                         Breach       PC  2011.0     Shooter
# 16591  16594            Myst IV: Revelation       PC  2004.0   Adventure
#
#                   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df[df['Genre'].str.contains('Simulation')]
# Out:
#         Rank                                  Name Platform    Year  \
# 10        11                            Nintendogs       DS  2005.0
# 41        42           Animal Crossing: Wild World       DS  2005.0
# 73        74             Animal Crossing: New Leaf      3DS  2012.0
# 83        84                            The Sims 3       PC  2009.0
# 153      154                          Cooking Mama       DS  2006.0
# ...      ...                                   ...      ...     ...
# 16480  16483                   Muv-Luv Alternative      PS3  2012.0
# 16511  16514                        Pony Friends 2       PC  2009.0
# 16514  16517  National Geographic Panda (JP sales)       DS  2008.0
# 16570  16573         Farming 2017 - The Simulation      PS4  2016.0
# 16592  16595                              Plushees       DS  2008.0
#
#             Genre          Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 10     Simulation           Nintendo      9.07     11.00      1.93
# ...

# %%
df2 = df.set_index('Rank')
df2
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
df2.filter(items = ['Name', 'Year', 'Genre'], axis = 0)
# Out:
# Empty DataFrame
# Columns: [Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
df2.filter(items = ['Name', 'Year', 'Genre'], axis = 1)
# Out:
#                                                    Name    Year         Genre
# Rank
# 1                                            Wii Sports  2006.0        Sports
# 2                                     Super Mario Bros.  1985.0      Platform
# 3                                        Mario Kart Wii  2008.0        Racing
# 4                                     Wii Sports Resort  2009.0        Sports
# 5                              Pokemon Red/Pokemon Blue  1996.0  Role-Playing
# ...                                                 ...     ...           ...
# 16596                Woody Woodpecker in Crazy Castle 5  2002.0      Platform
# 16597                     Men in Black II: Alien Escape  2003.0       Shooter
# 16598  SCORE International Baja 1000: The Official Game  2008.0        Racing
# 16599                                        Know How 2  2010.0        Puzzle
# 16600                                  Spirits & Spells  2003.0      Platform
#
# [16598 rows x 3 columns]

# %%
df2.filter(items = [169], axis = 0)
# Out:
#            Name Platform    Year Genre                    Publisher  NA_Sales  \
# Rank
# 169   Minecraft      PS3  2014.0  Misc  Sony Computer Entertainment      1.97
#
#       EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 169       2.51       0.0         0.94          5.42

# %%
df2.loc[420]
# Out:
# Name            Yokai Watch 2 Ganso/Honke
# Platform                              3DS
# Year                               2014.0
# Genre                        Role-Playing
# Publisher                        Nintendo
# NA_Sales                             0.03
# EU_Sales                              0.0
# JP_Sales                             3.18
# Other_Sales                           0.0
# Global_Sales                         3.22
# Name: 420, dtype: object

# %%
df2.iloc[420]
# Out:
# Name            007: Tomorrow Never Dies
# Platform                              PS
# Year                              1999.0
# Genre                            Shooter
# Publisher                Electronic Arts
# NA_Sales                            1.72
# EU_Sales                            1.33
# JP_Sales                             0.0
# Other_Sales                         0.16
# Global_Sales                        3.21
# Name: 421, dtype: object

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df[df['Rank'] <= 123]
# Out:
#      Rank                            Name Platform    Year         Genre  \
# 0       1                      Wii Sports      Wii  2006.0        Sports
# 1       2               Super Mario Bros.      NES  1985.0      Platform
# 2       3                  Mario Kart Wii      Wii  2008.0        Racing
# 3       4               Wii Sports Resort      Wii  2009.0        Sports
# 4       5        Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing
# ..    ...                             ...      ...     ...           ...
# 118   119                  Gears of War 2     X360  2008.0       Shooter
# 119   120      Uncharted 2: Among Thieves      PS3  2009.0        Action
# 120   121  Call of Duty 4: Modern Warfare      PS3  2007.0       Shooter
# 121   122                         FIFA 12      PS3  2011.0        Sports
# 122   123               Big Brain Academy       DS  2005.0          Misc
#
#                        Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df[df['Rank'] <= 123].sort_values(by = 'Year')
# Out:
#      Rank                          Name Platform    Year         Genre  \
# 89     90                       Pac-Man     2600  1982.0        Puzzle
# 9      10                     Duck Hunt      NES  1984.0       Shooter
# 1       2             Super Mario Bros.      NES  1985.0      Platform
# 96     97           Super Mario Bros. 2      NES  1988.0      Platform
# 22     23           Super Mario Bros. 3      NES  1988.0      Platform
# ..    ...                           ...      ...     ...           ...
# 109   110                     Fallout 4      PS4  2015.0  Role-Playing
# 92     93  Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 77     78                       FIFA 16      PS4  2015.0        Sports
# 101   102     Call of Duty: Black Ops 3     XOne  2015.0       Shooter
# 33     34     Call of Duty: Black Ops 3      PS4  2015.0       Shooter
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df[df['Rank'] <= 123].sort_values(by = ['Year', 'Rank'])
# Out:
#      Rank                          Name Platform    Year         Genre  \
# 89     90                       Pac-Man     2600  1982.0        Puzzle
# 9      10                     Duck Hunt      NES  1984.0       Shooter
# 1       2             Super Mario Bros.      NES  1985.0      Platform
# 22     23           Super Mario Bros. 3      NES  1988.0      Platform
# 96     97           Super Mario Bros. 2      NES  1988.0      Platform
# ..    ...                           ...      ...     ...           ...
# 33     34     Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# 77     78                       FIFA 16      PS4  2015.0        Sports
# 92     93  Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 101   102     Call of Duty: Black Ops 3     XOne  2015.0       Shooter
# 109   110                     Fallout 4      PS4  2015.0  Role-Playing
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df[df['Rank'] <= 123].sort_values(by = ['Year', 'Rank'], ascending = False)
# Out:
#      Rank                          Name Platform    Year         Genre  \
# 109   110                     Fallout 4      PS4  2015.0  Role-Playing
# 101   102     Call of Duty: Black Ops 3     XOne  2015.0       Shooter
# 92     93  Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 77     78                       FIFA 16      PS4  2015.0        Sports
# 33     34     Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# ..    ...                           ...      ...     ...           ...
# 96     97           Super Mario Bros. 2      NES  1988.0      Platform
# 22     23           Super Mario Bros. 3      NES  1988.0      Platform
# 1       2             Super Mario Bros.      NES  1985.0      Platform
# 9      10                     Duck Hunt      NES  1984.0       Shooter
# 89     90                       Pac-Man     2600  1982.0        Puzzle
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...

# %%
df[df['Rank'] <= 123].sort_values(by = ['Year', 'Rank'], ascending = [False, True])
# Out:
#      Rank                          Name Platform    Year         Genre  \
# 33     34     Call of Duty: Black Ops 3      PS4  2015.0       Shooter
# 77     78                       FIFA 16      PS4  2015.0        Sports
# 92     93  Star Wars Battlefront (2015)      PS4  2015.0       Shooter
# 101   102     Call of Duty: Black Ops 3     XOne  2015.0       Shooter
# 109   110                     Fallout 4      PS4  2015.0  Role-Playing
# ..    ...                           ...      ...     ...           ...
# 22     23           Super Mario Bros. 3      NES  1988.0      Platform
# 96     97           Super Mario Bros. 2      NES  1988.0      Platform
# 1       2             Super Mario Bros.      NES  1985.0      Platform
# 9      10                     Duck Hunt      NES  1984.0       Shooter
# 89     90                       Pac-Man     2600  1982.0        Puzzle
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# ...
