# %% [markdown]
# # Indexing

# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\vgSales.csv")

# %%
df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df = pd.read_csv(r"D:\vgSales.csv", index_col = "Name")

df
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Super Mario Bros.                                     2      NES  1985.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# Pokemon Red/Pokemon Blue                              5       GB  1996.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                          Genre   Publisher  \
# Name
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                                                    Name   Rank Platform  \
# 0                                            Wii Sports      1      Wii
# 1                                     Super Mario Bros.      2      NES
# 2                                        Mario Kart Wii      3      Wii
# 3                                     Wii Sports Resort      4      Wii
# 4                              Pokemon Red/Pokemon Blue      5       GB
# ...                                                 ...    ...      ...
# 16593                Woody Woodpecker in Crazy Castle 5  16596      GBA
# 16594                     Men in Black II: Alien Escape  16597       GC
# 16595  SCORE International Baja 1000: The Official Game  16598      PS2
# 16596                                        Know How 2  16599       DS
# 16597                                  Spirits & Spells  16600      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.set_index('Name')
# doesnt save
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Super Mario Bros.                                     2      NES  1985.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# Pokemon Red/Pokemon Blue                              5       GB  1996.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                          Genre   Publisher  \
# Name
# ...

# %%
df.set_index('Name', inplace = True)

df
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Super Mario Bros.                                     2      NES  1985.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# Pokemon Red/Pokemon Blue                              5       GB  1996.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                          Genre   Publisher  \
# Name
# ...

# %%
df.loc['Mario Kart Wii']
# Out:
# Rank                   3
# Platform             Wii
# Year              2008.0
# Genre             Racing
# Publisher       Nintendo
# NA_Sales           15.85
# EU_Sales           12.88
# JP_Sales            3.79
# Other_Sales         3.31
# Global_Sales       35.82
# Name: Mario Kart Wii, dtype: object

# %%
df.iloc[644]
# Out:
# Rank                        645
# Platform                    PS2
# Year                     2007.0
# Genre                    Racing
# Publisher       Electronic Arts
# NA_Sales                   0.69
# EU_Sales                    0.0
# JP_Sales                   0.04
# Other_Sales                1.68
# Global_Sales               2.41
# Name: Need for Speed: ProStreet, dtype: object

# %%
df
# Out:
#                                                    Rank Platform    Year  \
# Name
# Wii Sports                                            1      Wii  2006.0
# Super Mario Bros.                                     2      NES  1985.0
# Mario Kart Wii                                        3      Wii  2008.0
# Wii Sports Resort                                     4      Wii  2009.0
# Pokemon Red/Pokemon Blue                              5       GB  1996.0
# ...                                                 ...      ...     ...
# Woody Woodpecker in Crazy Castle 5                16596      GBA  2002.0
# Men in Black II: Alien Escape                     16597       GC  2003.0
# SCORE International Baja 1000: The Official Game  16598      PS2  2008.0
# Know How 2                                        16599       DS  2010.0
# Spirits & Spells                                  16600      GBA  2003.0
#
#                                                          Genre   Publisher  \
# Name
# ...

# %%
df.reset_index(inplace = True)

# %%
df
# Out:
#                                                    Name   Rank Platform  \
# 0                                            Wii Sports      1      Wii
# 1                                     Super Mario Bros.      2      NES
# 2                                        Mario Kart Wii      3      Wii
# 3                                     Wii Sports Resort      4      Wii
# 4                              Pokemon Red/Pokemon Blue      5       GB
# ...                                                 ...    ...      ...
# 16593                Woody Woodpecker in Crazy Castle 5  16596      GBA
# 16594                     Men in Black II: Alien Escape  16597       GC
# 16595  SCORE International Baja 1000: The Official Game  16598      PS2
# 16596                                        Know How 2  16599       DS
# 16597                                  Spirits & Spells  16600      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %%
df.set_index(['Year', 'Rank'])
# Out:
#                                                           Name Platform  \
# Year   Rank
# 2006.0 1                                            Wii Sports      Wii
# 1985.0 2                                     Super Mario Bros.      NES
# 2008.0 3                                        Mario Kart Wii      Wii
# 2009.0 4                                     Wii Sports Resort      Wii
# 1996.0 5                              Pokemon Red/Pokemon Blue       GB
# ...                                                        ...      ...
# 2002.0 16596                Woody Woodpecker in Crazy Castle 5      GBA
# 2003.0 16597                     Men in Black II: Alien Escape       GC
# 2008.0 16598  SCORE International Baja 1000: The Official Game      PS2
# 2010.0 16599                                        Know How 2       DS
# 2003.0 16600                                  Spirits & Spells      GBA
#
#                      Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Year   Rank
# ...

# %%
df.sort_index()
# Out:
#                                                    Name   Rank Platform  \
# 0                                            Wii Sports      1      Wii
# 1                                     Super Mario Bros.      2      NES
# 2                                        Mario Kart Wii      3      Wii
# 3                                     Wii Sports Resort      4      Wii
# 4                              Pokemon Red/Pokemon Blue      5       GB
# ...                                                 ...    ...      ...
# 16593                Woody Woodpecker in Crazy Castle 5  16596      GBA
# 16594                     Men in Black II: Alien Escape  16597       GC
# 16595  SCORE International Baja 1000: The Official Game  16598      PS2
# 16596                                        Know How 2  16599       DS
# 16597                                  Spirits & Spells  16600      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...
